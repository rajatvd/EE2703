# %% [markdown]
# # EE2703 Applied Programming Lab Final Exam
# 25th April, 2018
# *Rajat Vadiraj Dwaraknath
# EE16B033*

# %% [markdown]
# # Introduction
# This is the final exam. omgomgomg

# %%
import writefile_run

# %%
# %%writefile_run ee16b033_final_exam.py
#
# from pylab import *

# %%
# %%writefile_run ee16b033_final_exam.py -a
#
#
# rcParams["figure.figsize"] = 18,9
# rcParams["font.size"] = 18
# rcParams["text.usetex"] = True

# %% [markdown]
# # Current elements

# %%
# %%writefile_run ee16b033_final_exam.py -a
#
# N = 100
# a = 10
# phi_ = linspace(0,2*pi,N+1)[:-1]
# r_ = c_[a*cos(phi_),a*sin(phi_),zeros(N)]

# %%
scatter(r_[:,0],r_[:,1])
xlim(-18,18)
ylim(-12,12)
grid()

# %%
# %%writefile_run ee16b033_final_exam.py -a
#
#
# I =  c_[a*cos(phi_)*sin(phi_),-a*cos(phi_)*cos(phi_),zeros(N)]

# %%
# %%writefile_run ee16b033_final_exam.py -a
#
#
# quiver(r_[:,0],r_[:,1],I[:,0],I[:,1],scale=700,color='red')
# grid()
# xlim(-18,18)
# ylim(-12,12)
# show()

# %%
# %%writefile_run ee16b033_final_exam.py -a
#
#
# x = arange(3)-1
# z = arange(1,1001,1)
# xx,yy,zz = meshgrid(x,x,z)
# print(xx.shape)
# r = zeros((3,3,1000,3))
# r[:,:,:,0]=xx
# r[:,:,:,1]=yy
# r[:,:,:,2]=zz
# print(r.shape)
# print(r[2,0,23])
# Out:
# (3, 3, 1000)
# (3, 3, 1000, 3)
# [ -1.   1.  24.]

# %%
# %%writefile_run ee16b033_final_exam.py -a
#
#
#
# R=norm(tile(r,100).reshape(3,3,1000,100,3)-r_,axis=-1)
# R.shape
# Out:
# (3, 3, 1000, 100)

# %% [markdown]
# | Column 1 | Column 2 |
# |----------|----------|
# | foo      | bar      |
# | baz      | qux      |
# | quux     | quuz     |

# %%
norm([1,1,1])
# Out:
# 1.7320508075688772

# %%
plot(z,R[2,1,:,90],color='green')
plot(z,R[2,1,:,40],color='black')
xlim(0,10)
ylim(0,30)
# Out:
# (0, 30)

# %%
# %%writefile_run ee16b033_final_exam.py -a
#
#
# def calc(l):
#     return norm(r-r_[l],axis=-1)

# %%
calc(10).shape
# Out:
# (3, 3, 1000)

# %%
# %%writefile_run ee16b033_final_exam.py -a
#
#
# A_x = sum(cos(phi_)*exp(0.1j*R)*I[:,0]/R,axis=-1)
# A_y = sum(cos(phi_)*exp(0.1j*R)*I[:,1]/R,axis=-1)

# %%
# %%writefile_run ee16b033_final_exam.py -a
#
#
# #Bz = (A[2,1,:,1]-A[1,2,:,0]+A[0,1,:,1]-A[1,0,:,0])/4
# Bz = (A_y[1,2,:]-A_y[1,0,:]-(A_x[2,1,:]-A_x[0,1,:]))/4
# loglog()
# grid()
# plot(z,abs(Bz))
# show()

# %%
# %%writefile_run ee16b033_final_exam.py -a
#
#
# K=50
# y = log(abs(Bz))[K:]
# x = log(z[K:])
# A = c_[x,ones(1000)[K:]]
# m,b = lstsq(A,y)[0]
# plot(x,y)
# print(m,b)
# plot(x,m*x+b)
# grid()
# show()
# Out:
# -1.99734473131 5.50433376575

# %%
# %%writefile_run ee16b033_final_exam.py -a
#
#
# import scipy.signal as sp

# %%
# %%writefile_run ee16b033_final_exam.py -a

# %%
# %%writefile_run ee16b033_final_exam.py -a
